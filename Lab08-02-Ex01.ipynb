// %% [markdown]
// # Lab 8 Exercise 1
// ##  การสร้าง Class

// %% [markdown]
// 1. สร้าง console application project

// %% [markdown]
// 1.1 เรียก terminal (cmd) ขึ้นมา
//
// 1.2 ตรวจสอบให้แน่ใจว่าอยู่ใน folder หรือ directory ที่ต้องการสร้าง project
//
// 1.3 พิมพ์คำสั่งต่อไปนี้
//
// ```
//     dotnet new console --name Lab08_Ex01
// ```
//
// 1.4 ใช้คำสั่ง dir เพื่อตรวจสอบดูว่าโฟลเดอร์ของ project ได้ถูกสร้างขึ้นแล้วหรือยัง

// %% [markdown]
// 2. เปลี่ยน code ในไฟล์ program.cs ให้เป็นดังต่อไปนี้ (ตัวเลขข้างหน้า คือหมายเลขบรรทัด ไว้สำหรับอ้างอิง)
//
// > ```c#
// > 1.  Person p = new Person();
// > 2.  System.Console.WriteLine($"Type of p is {p.GetType()}");
// > 3.
// > 4.  class Person
// > 5.  {
// > 6.
// > 7.  }
// > ```

// %% [markdown]
// 3. Build project โดยการใช้คำสั่ง
//
// ```
// dotnet build  Lab08_Ex01
// ```

// %% [markdown]
// 4. บันทึกผลที่ได้จากการรันคำสั่งในข้อ 3

// %% [markdown]
// *คำตอบ*

// %% [markdown]
// ![image.png](attachment:image.png)

// %% [markdown]
// 5. Run project โดยการใช้คำสั่ง
//
// ```
// dotnet run --project Lab08_Ex01
// ```

// %% [markdown]
// 6. บันทึกผลที่ได้จากการรันคำสั่งในข้อ 5

// %% [markdown]
// *คำตอบ*

// %% [markdown]
// ![image.png](attachment:image.png)

// %% [markdown]
// 7. โค้ดต่อไปนี้สามารถรันได้ใน polyglot notebook หรือไม่

// %%
Person p = new Person();
System.Console.WriteLine($"Type of p is {p.GetType()}");

class Person
{

}
// Out:
// Type of p is Submission#1+Person

// %% [markdown]
// *คำตอบ*

// %% [markdown]
// สามารถรันได้ แต่ ไม่แสดง output ที่ต้องการจากคำสั่งได้

// %% [markdown]
// ## คำถาม

// %% [markdown]
// 1. Class ในภาษา C# คืออะไร

// %% [markdown]
// *คำตอบ*

// %% [markdown]
// แม่แบบของอ็อบเจกต์ ซึ่งใช้ในการกำหนดโครงสร้างและพฤติกรรมของอ็อบเจกต์ที่ถูกสร้างขึ้นจากคลาสนั้นๆ

// %% [markdown]
// 2. Class มีหน้าที่อะไร

// %% [markdown]
// *คำตอบ*

// %% [markdown]
// การเป็นแม่แบบในการสร้างออบเจกต์ โดยการกำหนดลักษณะและพฤติกรรมของอ็อบเจกต์ที่สามารถนำมาใช้ในโปรแกรมได้

// %% [markdown]
// 3. ทำไมเราต้องใช้ Class

// %% [markdown]
// *คำตอบ*

// %% [markdown]
// เราต้องใช้ class เพราะมันช่วยในการจัดระเบียบข้อมูลและพฤติกรรมของอ็อบเจกต์ ทำให้โค้ดอ่านง่าย

// %% [markdown]
// 4. ส่วนประกอบของ Class มีอะไรบ้าง

// %% [markdown]
// *คำตอบ*

// %% [markdown]
// Fields
// Properties
// Methods
// Constructors
// Destructors
// Events & Delegates

// %% [markdown]
// 5. Class และ Object แตกต่างกันอย่างไร

// %% [markdown]
// *คำตอบ*

// %% [markdown]
// class เป็นแม่แบบ ที่ใช้กำหนดโครงสร้างของอ็อบเจกต์ ส่วน objrect เป็นออบเจกต์จริงที่ถูกสร้างขึ้นจากคลาสนั้น

// %% [markdown]
// 6. การตั้งชื่อ Class มีหลักเกณฑ์อย่างไร

// %% [markdown]
// *คำตอบ*

// %% [markdown]
// ชื่อคลาสต้องใช้ตัวอักษรใหญ่ ตัวอักษรใหญ่

// %% [markdown]
// 7. คำสั่ง p.GetType() คืออะไร

// %% [markdown]
// *คำตอบ*

// %% [markdown]
// ประเภทของอ็อบเจกต์ p ที่ถูกสร้างขึ้น

// %% [markdown]
// 8. ผลที่ได้จากคำสั่ง  p.GetType() คืออะไร มันให้ข้อมูลอะไรแก่เราบ้าง

// %% [markdown]
// *คำตอบ*

// %% [markdown]
// ชื่อคลาส ข้อมูลเกี่ยวกับประเภท

// %% [markdown]
// 9. ในภาษา C# การประกาศ class ไว้ก่อนหรือหลังการสร้าง  object ต่างกันหรือไม่

// %% [markdown]
// *คำตอบ*

// %% [markdown]
// การประกาศ class ต้องทำก่อนการสร้าง object เนื่องจาก class คือแม่แบบที่ใช้ในการสร้างอ็อบเจกต์ ดังนั้นเมื่อคุณต้องการสร้างอ็อบเจกต์จากคลาสใด ๆ ต้องประกาศคลาสนั้นก่อนในโค้ด
